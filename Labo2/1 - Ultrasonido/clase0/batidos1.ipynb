# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data1 = np.loadtxt('WaveData4300.csv',delimiter=',',skiprows=2)
data2 = np.loadtxt('WaveData4301.csv',delimiter=',',skiprows=2)
batidos = data1 + data2
x = np.linspace(0,100,len(batidos[:,1])-60)
plt.plot(x,batidos[:,1][0:-60])
