# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from scipy.optimize import curve_fit as cf
from scipy.stats import chi2
from math import floor
from scipy.interpolate import UnivariateSpline
import scipy.interpolate as si
from scipy.signal import find_peaks as fpk
from scipy.optimize import curve_fit as cf

# %%
mpl.rcParams['lines.linewidth'] = 2
mpl.rcParams['lines.markersize'] = 4
mpl.rcParams['figure.autolayout'] = True
mpl.rcParams['font.size'] = 20
mpl.rcParams['errorbar.capsize'] = 3
mpl.rcParams['lines.markeredgewidth'] = 1
mpl.rcParams["figure.figsize"] = (11,6)
mpl.rcParams['axes.axisbelow'] = True

c_list = ['tab:orange','crimson','forestgreen','darkmagenta','lightseagreen']

# %%
def chi2_red(y,y_err,x,func,popt):
    puntos = len(y)
    params = len(popt)
    grados_lib = puntos - params - 1
    y_ajuste = func(x,*popt)
    
    chi_cuadrado = np.sum(((y-y_ajuste)/y_err)**2)
    chi_reducido = chi_cuadrado/grados_lib
    return chi_reducido

def r2(y,x,lineal,pars):
    r2 = 1 - (np.sum((y-lineal(x,*pars))**2)/np.sum((y - np.mean(y))**2))
    return r2

lineal = lambda x,a,b : a*x+b
dcmls = lambda x : -int(floor(np.log10(abs(x))))

# %%
data1 = np.loadtxt('malus600.csv',delimiter=',',unpack=True,skiprows=1)
ruido1,ang1,err_ang1,i1,std1 = data1
err_i1 = np.zeros_like(i1)
for i in range(len(err_i1)):
    err_i1[i] += max(ruido1[i],std1[i])

pars1,cov1 = cf(lineal,ang1[4:-7],i1[4:-7],sigma=err_i1[4:-7],absolute_sigma=True)
a1,b1 = pars1
err_a1 = cov1[0,0]
err_b1 = cov1[1,1]
x_adj1 = np.linspace(ang1[4],ang1[-7],100)
y_adj1 = a1*x_adj1+b1

print(ang1[4],err_ang1[4],ang1[-7],err_ang1[-7],i1[4],err_i1[4],i1[-7],err_i1[-7])
print(chi2_red(i1[4:-7],err_i1[4:-7],ang1[4:-7],lineal,pars1))
print(r2(i1[4:-7],ang1[4:-7],lineal,pars1))

plt.plot(x_adj1,y_adj1,'crimson',label='ajuste',zorder=1)
plt.errorbar(ang1,i1,yerr=err_i1,xerr=err_ang1,fmt='None',ecolor='navy',label='datos',zorder=2)
plt.scatter(ang1,i1,c='navy',zorder=3)
plt.grid()
plt.xlabel('ángulo [°]')
plt.ylabel('Intensidad [lx]')
plt.axvline(x=ang1[4],ls='--',c='darkgreen',label='rango lineal',zorder=1)
plt.axvline(x=ang1[-7],ls='--',c='darkgreen',zorder=1)
plt.legend()
plt.savefig('malus_600.png')
# Out:
# 20.0 0.1 60.0 0.1 22.6 0.6 111.6 0.6
# 3.7744841849574717
# 0.998050386728474

# %%
data2 = np.loadtxt('malus 6000.csv',delimiter=',',unpack=True,skiprows=1)
ruido2,ang2,err_ang2,i2,std2 = data2
err_i2 = np.zeros_like(i2)
for i in range(len(err_i2)):
    err_i2[i] += max(ruido2[i],std2[i])

pars2,cov2 = cf(lineal,ang2[4:-7],i2[4:-7],sigma=err_i2[4:-7],absolute_sigma=True)
a2,b2 = pars2
err_a2 = cov2[0,0]
err_b2 = cov2[1,1]
x_adj2 = np.linspace(ang2[4],ang2[-7],100)
y_adj2 = a2*x_adj2+b2

print(ang2[4],err_ang2[4],ang2[-7],err_ang2[-7],i2[4],err_i2[4],i2[-7],err_i2[-7])
print(chi2_red(i2[4:-7],err_i2[4:-7],ang2[4:-7],lineal,pars2))
print(r2(i2[4:-7],ang2[4:-7],lineal,pars2))

plt.plot(x_adj2,y_adj2,'crimson',label='ajuste',zorder=1)
plt.errorbar(ang2,i2,yerr=err_i2,xerr=err_ang2,fmt='None',ecolor='navy',label='datos',zorder=2)
plt.scatter(ang2,i2,c='navy',zorder=3)
plt.grid()
plt.xlabel('ángulo [°]')
plt.ylabel('Amplitud [lx]')
plt.axvline(x=ang2[4],ls='--',c='darkgreen',label='rango lineal',zorder=1)
plt.axvline(x=ang2[-7],ls='--',c='darkgreen',zorder=1)
plt.legend()
plt.savefig('malus_6000.png')
# Out:
# 25.0 0.1 60.0 0.1 319.6 4.2 1366.7 1.92
# 14.464590651493628
# 0.997330532388637

# %%
data3 = np.loadtxt('malus150000.csv',delimiter=',',unpack=True,skiprows=1)
ruido3,ang3,err_ang3,i3,std3 = data3
ang3 = 75-ang3
idx_sort3 = np.argsort(ang3)
ang3 = ang3[idx_sort3]
err_ang3 = err_ang3[idx_sort3]
i3 = i3[idx_sort3]
std3 = std3[idx_sort3]
err_i3 = np.zeros_like(i3)
for i in range(len(err_i3)):
    err_i3[i] += max(ruido3[i],std3[i])

pars3,cov3 = cf(lineal,ang3[5:-9],i3[5:-9],sigma=err_i3[5:-9],absolute_sigma=True)
a3,b3 = pars3
err_a3 = cov3[0,0]
err_b3 = cov3[1,1]
x_adj3 = np.linspace(ang3[5],ang3[-9],100)
y_adj3 = a3*x_adj3+b3

print(ang3[5],err_ang3[5],ang3[-9],err_ang3[-9],i3[5],err_i3[5],i3[-9],err_i3[-9])
print(chi2_red(i3[5:-9],err_i3[5:-9],ang3[5:-9],lineal,pars3))
print(r2(i3[5:-9],ang3[5:-9],lineal,pars3))

plt.plot(x_adj3,y_adj3,'crimson',label='ajuste',zorder=1)
plt.errorbar(ang3,i3,yerr=err_i3,xerr=err_ang3,fmt='None',ecolor='navy',label='datos',zorder=2)
plt.scatter(ang3,i3,c='navy',zorder=3)
plt.grid()
plt.xlabel('ángulo [°]')
plt.ylabel('Intensidad [lx]')
plt.axvline(x=ang3[5],ls='--',c='darkgreen',label='rango lineal',zorder=1)
plt.axvline(x=ang3[-9],ls='--',c='darkgreen',zorder=1)
plt.legend()
plt.savefig('malus_150000.png')
# Out:
# 25.0 0.1 60.0 0.1 2666.0 19.0 11007.0 19.0
# 11.948555599525132
# 0.999568265590586

# %%
I_tot = 47875
I_max = 29502
I_min = 284
err_I_tot = 19
err_I_max = 19
err_I_min = 0.7

V2 = (I_max-I_min)/(I_max+I_min)
err_V2 = np.sqrt(((1/(I_min+I_max)-(I_max-I_min)/(I_max+I_min)**2)*err_I_max)**2+((-1/(I_max+I_min)-(I_max-I_min)/(I_max+I_min)**2)*err_I_min)**2)
print(V2,err_V2)
# Out:
# 0.9809306385550258 4.811673152766739e-05
