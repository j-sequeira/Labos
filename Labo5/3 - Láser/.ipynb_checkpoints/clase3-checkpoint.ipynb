# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import os
from scipy.optimize import curve_fit as cf

# %%
mpl.rcParams['lines.linewidth'] = 2
mpl.rcParams['lines.markersize'] = 4
mpl.rcParams['figure.autolayout'] = True
mpl.rcParams['font.size'] = 15
mpl.rcParams['errorbar.capsize'] = 3
mpl.rcParams['lines.markeredgewidth'] = 1
mpl.rcParams['axes.axisbelow'] = True

# %%
df = pd.read_csv('Datos laser - Perfil lineal clase3.csv',header=0,names=['pos','pot'])
df.pos = df.pos*0.5 # una vuelta del tornillo del microposicionador es desplazar un micrómetro/micrón

# %%
from scipy.special import erf
perfil_gauss = lambda x,a,b,c,d : a*erf((x-b)/(np.sqrt(2)*c))+d

# %%
pars,cov = cf(perfil_gauss,df.pos,df.pot,p0=[-10,3,6,8.75])
a,b,c,d = pars

x_adj = np.linspace(min(df.pos),max(df.pos),100)
y_adj = perfil_gauss(x_adj,*pars)

plt.scatter(df.pos,df.pot,c='navy',label='Datos',zorder=2)
plt.plot(x_adj,y_adj,'crimson',label='Ajuste',zorder=1)
plt.xlabel('Posición del filo [\u00B5m]')
plt.ylabel('P [mW]')
plt.grid()
plt.legend()
plt.tight_layout()
plt.savefig('plots/perfill gauss.png')

# %%
gaussian = lambda x,a,b,c : a*np.exp(-(x-b)**2/(2*c**2))

derivada_ex = np.gradient(df.pot,df.pos)
pars2,cov2 = cf(gaussian,df.pos,derivada_ex,p0=[np.sqrt(2/np.pi)*a/c,b,c])
derivada_adj_ex = gaussian(x_adj,*pars2)

plt.scatter(df.pos,-derivada_ex,c='navy',label='Derivada')
plt.plot(x_adj,-derivada_adj_ex,'crimson',label='Ajuste de la derivada')
derivada_adj = gaussian(x_adj,np.sqrt(2/np.pi)*a/c,b,c)
plt.plot(x_adj,-derivada_adj,'forestgreen',label='Derivada del ajuste')
plt.grid()
plt.xlabel('Posición del filo [\u00B5m]')
plt.ylabel('Perfil de intensidad [mW\u00B5m]')
plt.legend(fontsize=10,loc=2)
plt.tight_layout()
plt.axhline(np.sqrt(2/np.pi)*abs(a)/c/np.e)
plt.axvline(b+c)
plt.axvline(b-c)
plt.arrow(b,np.sqrt(2/np.pi)*abs(a)/c/np.e,c,0,head_length=0.1,head_width=0.75,length_includes_head=True,facecolor='None',edgecolor='forestgreen')
plt.arrow(b,np.sqrt(2/np.pi)*abs(a)/c/np.e,-c,0,head_length=0.1,head_width=0.75,length_includes_head=True,facecolor='None',edgecolor='forestgreen')
print(2*c,2*np.sqrt(cov[2,2]))
print(2*pars2[2],2*np.sqrt(cov2[2,2]))
# Out:
# 0.8706350946007873 0.08913929528373532
# 0.8949178221834387 0.12983994957130213

# %%
np.log(np.e)
# Out:
# 1.0

# %%
df = pd.read_csv('espectro verde bien.csv',header=None,names=['long','I'])
plt.plot(df.long,df.I,c='forestgreen')
plt.xlim(470,600)
plt.ylim(0.05,0.9)
plt.axvline(587)

# %%
from scipy.signal import find_peaks as fp
from scipy.signal import savgol_filter as savgol

# %%
df.long[1530]
# Out:
# 525.3126221

# %%
cmap = mpl.colormaps['seismic']
colors = cmap(np.linspace(0,1,12))

pks_centrales = []
for i in range(1,12):
    df = pd.read_csv(f'verde/{i*30}.csv',header=None,names=['long','I'])
    plt.plot(df.long,df.I,c=colors[i],alpha=1-i*0.05,zorder=1)
    plt.xlim(450,630)
    plt.ylim(0,0.45)
    pks = fp(df.I[1530:1600],distance=60)[0] + 1530
    print(pks)
    plt.scatter(df.long[pks],df.I[pks],c='forestgreen',zorder=3)
    
plt.grid()
plt.xlabel('\u03BB [nm]')
plt.ylabel('I [u.a.]')
plt.tight_layout()
# Out:
# [1567]
# [1567]
# [1567]
# [1583]
# [1567]
# [1553]
# [1581]
# [1568]
# [1566]
# [1569]
# [1568]
