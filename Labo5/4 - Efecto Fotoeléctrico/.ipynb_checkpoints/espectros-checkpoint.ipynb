# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import os

# %%
mpl.rcParams['lines.linewidth'] = 2
mpl.rcParams['lines.markersize'] = 4
mpl.rcParams['figure.autolayout'] = True
mpl.rcParams['font.size'] = 15
mpl.rcParams['errorbar.capsize'] = 3
mpl.rcParams['lines.markeredgewidth'] = 1
mpl.rcParams['axes.axisbelow'] = True

# %%
lambdas = np.arange(440,740,20)

norm = mpl.colors.Normalize(vmin=lambdas.min(), vmax=lambdas.max())
cmap = mpl.cm.seismic

# Plotting with colormap
fig, ax = plt.subplots(figsize=(8, 6))

for i in range(len(lambdas)):
    df = pd.read_csv(f'espectros filtrados/{int(lambdas[i])}.csv', header=None, names=['long', 'I'])
    color = cmap(norm(lambdas[i]))
    plt.plot(df.long, df.I,color=color)#, label=f'{lambdas[i]} nm')

sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])
cbar = cbar = fig.colorbar(sm, ax=ax, orientation="vertical")
cbar.set_label('Longitud de onda del filtro [nm]')

# Axis labels and grid
plt.grid()
plt.xlabel('\u03BB [nm]')
plt.ylabel('Intensidad [u.a.]')
plt.tight_layout()
plt.savefig('plots/espectros.png')

# %%
df = pd.read_csv(f'espectros filtrados/440.csv',header=None,names=['long','I'])
plt.plot(df.long,df.I)

# %%
df = pd.read_csv('clase1/440/0.5.csv')
df
# Out:
#     Unnamed: 0           V_m    fase            Re            Im
# 0            0  6.934920e-12  -1.638  6.934920e-12 -2.273750e-13
# 1            1  5.229620e-12 -12.294  5.115940e-12 -1.136880e-12
# 2            2  6.934920e-12  -2.184  6.934920e-12 -3.410620e-13
# 3            3  3.751690e-12 -32.004  3.183250e-12 -2.046380e-12
# 4            4  4.661190e-12  19.212  4.320130e-12  1.477940e-12
# 5            5  4.206440e-12   8.130  4.092750e-12  5.684380e-13
# 6            6  4.206440e-12 -24.144  3.865380e-12 -1.819000e-12
# 7            7  5.002250e-12  -6.012  5.002250e-12 -5.684380e-13
# 8            8  4.774870e-12 -23.718  4.320130e-12 -2.046380e-12
# 9            9  5.229620e-12 -27.858  4.661190e-12 -2.501120e-12
# 10          10  4.206440e-12  26.964  3.751690e-12  1.932690e-12
# 11          11  3.183250e-12  -8.130  3.183250e-12 -5.684380e-13
# 12          12  4.661190e-12 -32.094  3.865380e-12 -2.501120e-12
# 13          13  6.707550e-12 -10.866  6.593860e-12 -1.364250e-12
# 14          14  7.048610e-12   4.806  7.048610e-12  5.684380e-13
