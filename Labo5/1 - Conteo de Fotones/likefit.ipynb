# %%
import likefit

# %%
help(likefit.Poisson)
# Out:
# Help on class Poisson in module likefit:
#
# class Poisson(LikelihoodFitter)
#  |  Poisson(xdata, nevents, model)
#  |
#  |  Poisson fitter based on the LikelihoodFitter base class.
#  |
#  |  Parameters
#  |  ----------
#  |  xdata : array_like
#  |      The independent variable data.
#  |  nevents : array_like
#  |      The number of observed events data.
#  |  model : callable
#  |      The model function to fit the data.
#  |
#  |  Attributes
#  |  ----------
#  |  xdata : array_like
#  |      The independent variable data.
#  |  nevents : array_like
#  |      The number of observed events data.
#  |  model : callable
#  |      The model function to fit the data.
#  |
#  |  Method resolution order:
#  |      Poisson
#  |      LikelihoodFitter
#  |      abc.ABC
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, xdata, nevents, model)
#  |      Initialize the Poisson fitter instance.
#  |
#  |      Parameters
#  |      ----------
# ...
